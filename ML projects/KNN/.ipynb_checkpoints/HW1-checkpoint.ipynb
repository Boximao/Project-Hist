# %% [markdown]
# # Che-Wei Yeh
# # 7415538737

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import DistanceMetric

# %% [markdown]
# # (a)

# %%
data=pd.read_table('data\column_2C.dat',sep=' ',header=None)
data
# Out:
#          0      1      2      3       4      5   6
# 0    63.03  22.55  39.61  40.48   98.67  -0.25  AB
# 1    39.06  10.06  25.02  29.00  114.41   4.56  AB
# 2    68.83  22.22  50.09  46.61  105.99  -3.53  AB
# 3    69.30  24.65  44.31  44.64  101.87  11.21  AB
# 4    49.71   9.65  28.32  40.06  108.17   7.92  AB
# ..     ...    ...    ...    ...     ...    ...  ..
# 305  47.90  13.62  36.00  34.29  117.45  -4.25  NO
# 306  53.94  20.72  29.22  33.22  114.37  -0.42  NO
# 307  61.45  22.69  46.17  38.75  125.67  -2.71  NO
# 308  45.25   8.69  41.58  36.56  118.55   0.21  NO
# 309  33.84   5.07  36.64  28.77  123.95  -0.20  NO
#
# [310 rows x 7 columns]

# %% [markdown]
# # (b)

# %% [markdown]
# ### (i)

# %%
df=data.copy()

# %%
label_binarizer = LabelBinarizer()

# %%
# Turning AB and NO into 1 and 0
Normality = label_binarizer.fit_transform(df[6])
df2=pd.DataFrame(Normality)
df[7]=df2
for i in df.index:
    df[7][i]=1-df[7][i]
df
# Out:
# <ipython-input-5-7d83f592d8ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[7][i]=1-df[7][i]
#          0      1      2      3       4      5   6  7
# 0    63.03  22.55  39.61  40.48   98.67  -0.25  AB  1
# 1    39.06  10.06  25.02  29.00  114.41   4.56  AB  1
# 2    68.83  22.22  50.09  46.61  105.99  -3.53  AB  1
# 3    69.30  24.65  44.31  44.64  101.87  11.21  AB  1
# 4    49.71   9.65  28.32  40.06  108.17   7.92  AB  1
# ..     ...    ...    ...    ...     ...    ...  .. ..
# 305  47.90  13.62  36.00  34.29  117.45  -4.25  NO  0
# 306  53.94  20.72  29.22  33.22  114.37  -0.42  NO  0
# 307  61.45  22.69  46.17  38.75  125.67  -2.71  NO  0
# 308  45.25   8.69  41.58  36.56  118.55   0.21  NO  0
# 309  33.84   5.07  36.64  28.77  123.95  -0.20  NO  0
#
# [310 rows x 8 columns]

# %%
df=df.drop([6],axis=1)
df
# Out:
#          0      1      2      3       4      5  7
# 0    63.03  22.55  39.61  40.48   98.67  -0.25  1
# 1    39.06  10.06  25.02  29.00  114.41   4.56  1
# 2    68.83  22.22  50.09  46.61  105.99  -3.53  1
# 3    69.30  24.65  44.31  44.64  101.87  11.21  1
# 4    49.71   9.65  28.32  40.06  108.17   7.92  1
# ..     ...    ...    ...    ...     ...    ... ..
# 305  47.90  13.62  36.00  34.29  117.45  -4.25  0
# 306  53.94  20.72  29.22  33.22  114.37  -0.42  0
# 307  61.45  22.69  46.17  38.75  125.67  -2.71  0
# 308  45.25   8.69  41.58  36.56  118.55   0.21  0
# 309  33.84   5.07  36.64  28.77  123.95  -0.20  0
#
# [310 rows x 7 columns]

# %%
df.columns=['Pelvic_Incidence','Pelvic_tilt','Lumbar_Lordosis_Angle','Sacrol_Slope','Pelvic_Radius','NA','Grade_of_S']
df
# Out:
#      Pelvic_Incidence  Pelvic_tilt  Lumbar_Lordosis_Angle  Sacrol_Slope  \
# 0               63.03        22.55                  39.61         40.48
# 1               39.06        10.06                  25.02         29.00
# 2               68.83        22.22                  50.09         46.61
# 3               69.30        24.65                  44.31         44.64
# 4               49.71         9.65                  28.32         40.06
# ..                ...          ...                    ...           ...
# 305             47.90        13.62                  36.00         34.29
# 306             53.94        20.72                  29.22         33.22
# 307             61.45        22.69                  46.17         38.75
# 308             45.25         8.69                  41.58         36.56
# 309             33.84         5.07                  36.64         28.77
#
#      Pelvic_Radius     NA  Grade_of_S
# 0            98.67  -0.25           1
# ...

# %%
colors={1:'red',0:'blue'}

plt.scatter(df.Pelvic_Incidence,df.Grade_of_S,c=df.Grade_of_S.map(colors))
plt.xlabel('Pelvic_Incidence')
plt.ylabel('Normality')
# Out:
# Text(0, 0.5, 'Normality')

# %%
colors={1:'red',0:'blue'}

plt.scatter(df.Pelvic_tilt,df.Grade_of_S,c=df.Grade_of_S.map(colors))
plt.xlabel('Pelvic_tilt')
plt.ylabel('Normality')
# Out:
# Text(0, 0.5, 'Normality')

# %%
colors={1:'red',0:'blue'}

plt.scatter(df.Lumbar_Lordosis_Angle,df.Grade_of_S,c=df.Grade_of_S.map(colors))
plt.xlabel('Lumbar_Lordosis_Angle')
plt.ylabel('Normality')
# Out:
# Text(0, 0.5, 'Normality')

# %%
colors={1:'red',0:'blue'}

plt.scatter(df.Sacrol_Slope,df.Grade_of_S,c=df.Grade_of_S.map(colors))
plt.xlabel('Sacrol_Slope')
plt.ylabel('Normality')
# Out:
# Text(0, 0.5, 'Normality')

# %%
colors={1:'red',0:'blue'}

plt.scatter(df.Pelvic_Radius,df.Grade_of_S,c=df.Grade_of_S.map(colors))
plt.xlabel('Pelvic_Radius')
plt.ylabel('Normality')
# Out:
# Text(0, 0.5, 'Normality')

# %% [markdown]
# ### (ii)

# %%
sns.boxplot(x=df.Grade_of_S,y=df.Pelvic_Incidence)
# Out:
# <AxesSubplot:xlabel='Grade_of_S', ylabel='Pelvic_Incidence'>

# %%
sns.boxplot(x=df.Grade_of_S,y=df.Pelvic_tilt)
# Out:
# <AxesSubplot:xlabel='Grade_of_S', ylabel='Pelvic_tilt'>

# %%
sns.boxplot(x=df.Grade_of_S,y=df.Lumbar_Lordosis_Angle)
# Out:
# <AxesSubplot:xlabel='Grade_of_S', ylabel='Lumbar_Lordosis_Angle'>

# %%
sns.boxplot(x=df.Grade_of_S,y=df.Sacrol_Slope)
# Out:
# <AxesSubplot:xlabel='Grade_of_S', ylabel='Sacrol_Slope'>

# %%
sns.boxplot(x=df.Grade_of_S,y=df.Pelvic_Radius)
# Out:
# <AxesSubplot:xlabel='Grade_of_S', ylabel='Pelvic_Radius'>

# %% [markdown]
# ### (iii)

# %%
# seperate into 0 and 1
df_0=df[df.Grade_of_S==0]
df_1=df[df.Grade_of_S==1]

# %%
train_0=df_0.iloc[:70]
train_1=df_1.iloc[:140]
test_0=df_0.iloc[70:]
test_1=df_1.iloc[140:]

# %%
# merge into training and testing sets
train_set=[train_0,train_1]
train=pd.concat(train_set)
test_set=[test_0,test_1]
test=pd.concat(test_set)
train.describe()
# Out:
#        Pelvic_Incidence  Pelvic_tilt  Lumbar_Lordosis_Angle  Sacrol_Slope  \
# count        210.000000   210.000000             210.000000    210.000000
# mean          58.242429    17.226429              48.788143     41.016381
# std           16.697671     9.130719              16.895211     13.454336
# min           26.150000    -6.550000              14.000000     13.370000
# 25%           44.640000    10.760000              35.925000     31.705000
# 50%           55.120000    16.525000              47.000000     39.885000
# 75%           70.355000    21.895000              59.202500     49.762500
# max          129.830000    48.070000              93.890000    121.430000
#
#        Pelvic_Radius          NA  Grade_of_S
# count     210.000000  210.000000  210.000000
# mean      120.014810   22.158905    0.666667
# std        11.445649   39.749669    0.472531
# min        84.240000  -11.060000    0.000000
# 25%       113.322500    0.850000    0.000000
# ...

# %%
train_x=train.iloc[:,:6]
train_y=train.iloc[:,6]
test_x=test.iloc[:,:6]
test_y=test.iloc[:,6]
test_x.describe()
# Out:
#        Pelvic_Incidence  Pelvic_tilt  Lumbar_Lordosis_Angle  Sacrol_Slope  \
# count         100.00000   100.000000             100.000000    100.000000
# mean           65.23000    18.207500              58.530100     47.022600
# std            17.47132    11.660512              20.171759     12.470495
# min            33.04000    -3.760000              19.070000     19.290000
# 25%            51.01750    10.002500              43.175000     36.635000
# 50%            64.44500    15.315000              58.480000     45.950000
# 75%            78.61250    24.082500              72.020000     55.455000
# max           118.14000    49.430000             125.740000     79.700000
#
#        Pelvic_Radius          NA
# count     100.000000  100.000000
# mean      113.522600   34.986200
# std        15.753521   30.899503
# min        70.080000   -8.940000
# 25%       103.387500    6.032500
# 50%       115.760000   31.775000
# 75%       125.055000   53.137500
# ...

# %% [markdown]
# # (c)

# %% [markdown]
# ### (i)

# %%
knn=KNeighborsClassifier(p=2)
scaler = StandardScaler()

# %% [markdown]
# ### (ii)

# %%
knn=KNeighborsClassifier(n_neighbors=5,p=2)

# %%
scaler.fit(train_x)
scaler.fit(test_x)
# Out:
# StandardScaler()

# %%
train_x = scaler.transform(train_x)
test_x = scaler.transform(test_x)

# %%
knn.fit(train_x,train_y)
# Out:
# KNeighborsClassifier()

# %%
y_pred=knn.predict(test_x)

# %%
# testing error
result=[]
error=[]
for k in range(208,0,-1):
    knn=KNeighborsClassifier(n_neighbors=k)
    knn.fit(train_x,train_y)
    y_pred=knn.predict(test_x)
    r=accuracy_score(test_y,y_pred)
    err=1-r
    result.append([k,r])
    error.append([k,err])
result
# Out:
# [[208, 0.7],
#  [207, 0.7],
#  [206, 0.7],
#  [205, 0.7],
#  [204, 0.7],
#  [203, 0.7],
#  [202, 0.7],
#  [201, 0.7],
#  [200, 0.7],
#  [199, 0.7],
#  [198, 0.7],
#  [197, 0.7],
#  [196, 0.7],
#  [195, 0.7],
#  [194, 0.7],
#  [193, 0.7],
#  [192, 0.7],
#  [191, 0.7],
#  [190, 0.7],
#  [189, 0.7],
#  [188, 0.7],
#  [187, 0.7],
#  [186, 0.7],
#  [185, 0.7],
#  [184, 0.7],
#  [183, 0.7],
#  [182, 0.7],
#  [181, 0.7],
#  [180, 0.7],
#  [179, 0.7],
#  [178, 0.7],
#  [177, 0.7],
#  [176, 0.7],
#  [175, 0.7],
#  [174, 0.7],
#  [173, 0.7],
#  [172, 0.7],
#  [171, 0.7],
#  [170, 0.7],
#  [169, 0.7],
#  [168, 0.7],
#  [167, 0.7],
#  [166, 0.7],
#  [165, 0.7],
#  [164, 0.7],
#  [163, 0.7],
#  [162, 0.7],
#  [161, 0.7],
#  [160, 0.7],
#  [159, 0.7],
#  [158, 0.7],
#  [157, 0.7],
#  [156, 0.7],
#  [155, 0.7],
#  [154, 0.7],
#  [153, 0.7],
#  [152, 0.7],
#  [151, 0.7],
#  [150, 0.7],
#  [149, 0.7],
#  [148, 0.7],
#  [147, 0.7],
#  [146, 0.7],
#  [145, 0.7],
#  [144, 0.7],
#  [143, 0.7],
# ...

# %%
df_error=pd.DataFrame(error)
df_error.columns=['k_value','error_rate']
plt.scatter(x=df_error.k_value,y=df_error.error_rate,alpha=0.8)
plt.xlim(max(df_error.k_value), 0)
plt.title('testing error')
# Out:
# Text(0.5, 1.0, 'testing error')

# %%
# training error
result_train=[]
error_train=[]
for k in range(208,0,-1):
    knn=KNeighborsClassifier(n_neighbors=k)
    knn.fit(train_x,train_y)
    y_pred=knn.predict(train_x)
    r=accuracy_score(train_y,y_pred)
    err=1-r
    result_train.append([k,r])
    error_train.append([k,err])
error_train=pd.DataFrame(error_train)
error_train.columns=['k','error_rate']
plt.scatter(x=error_train.k,y=error_train.error_rate,alpha=0.8)
plt.xlim(max(error_train.k), 0)
plt.title('training error')
# Out:
# Text(0.5, 1.0, 'training error')

# %%
df_result=pd.DataFrame(result)
df_result.columns=['k','Accuracy']
df_result
# Out:
#        k  Accuracy
# 0    208      0.70
# 1    207      0.70
# 2    206      0.70
# 3    205      0.70
# 4    204      0.70
# ..   ...       ...
# 203    5      0.86
# 204    4      0.88
# 205    3      0.87
# 206    2      0.85
# 207    1      0.88
#
# [208 rows x 2 columns]

# %%
# most suitable K 
print('Most suitable K from testing dataset and the accuracy')
df_max=df_result.Accuracy
m=df_max.max()
df_acc=df_result[(df_result.Accuracy==m)]
df_acc
# Out:
# Most suitable K from testing dataset and the accuracy
#       k  Accuracy
# 182  26      0.88
# 190  18      0.88
# 204   4      0.88
# 207   1      0.88

# %%
# confusion matrix
knn=KNeighborsClassifier(n_neighbors=4)
knn.fit(train_x,train_y)
y_pred=knn.predict(test_x)
r=accuracy_score(test_y,y_pred)
con_mat=confusion_matrix(test_y,y_pred)
con_mat
# Out:
# array([[23,  7],
#        [ 5, 65]], dtype=int64)

# %%
true_positive=con_mat[[1],[1]]/(con_mat[[1],[1]]+con_mat[[1],[0]])
print(f'True positive rate is {true_positive}')
true_negative=con_mat[[0],[0]]/(con_mat[[0],[0]]+con_mat[[0],[1]])
print(f'True negative rate is {true_negative}')
precision=con_mat[[1],[1]]/(con_mat[[1],[1]]+con_mat[[0],[1]])
print(f'Precision is {precision}')
F1=(true_positive*precision)/(true_positive+precision)
print(f'F1 score is {F1}')
# Out:
# True positive rate is [0.92857143]
# True negative rate is [0.76666667]
# Precision is [0.90277778]
# F1 score is [0.45774648]

# %% [markdown]
# ### (iii) need plot

# %%
result_2=[]
error_2=[]

# %%
for N in range(10,220,10):
    c0=N//3
    c1=N-c0
    t0=train_0.iloc[:c0+1]
    t1=train_1.iloc[:c1+1]
    train_set=[t0,t1]
    train_x2=train.iloc[:,:6]
    train_y2=train.iloc[:,6]
    scaler.fit(train_x2)
    train_x2 = scaler.transform(train_x2)
    for k in range(1,N,5):
        knn=KNeighborsClassifier(n_neighbors=k)
        knn.fit(train_x2,train_y2)
        y_pred=knn.predict(test_x)
        r=accuracy_score(test_y,y_pred)
        err=1-r
        result_2.append([N,k,r])
        error_2.append([N,k,err])
        
result_2
# Out:
# [[10, 1, 0.67],
#  [10, 6, 0.75],
#  [20, 1, 0.67],
#  [20, 6, 0.75],
#  [20, 11, 0.73],
#  [20, 16, 0.74],
#  [30, 1, 0.67],
#  [30, 6, 0.75],
#  [30, 11, 0.73],
#  [30, 16, 0.74],
#  [30, 21, 0.77],
#  [30, 26, 0.77],
#  [40, 1, 0.67],
#  [40, 6, 0.75],
#  [40, 11, 0.73],
#  [40, 16, 0.74],
#  [40, 21, 0.77],
#  [40, 26, 0.77],
#  [40, 31, 0.77],
#  [40, 36, 0.79],
#  [50, 1, 0.67],
#  [50, 6, 0.75],
#  [50, 11, 0.73],
#  [50, 16, 0.74],
#  [50, 21, 0.77],
#  [50, 26, 0.77],
#  [50, 31, 0.77],
#  [50, 36, 0.79],
#  [50, 41, 0.74],
#  [50, 46, 0.77],
#  [60, 1, 0.67],
#  [60, 6, 0.75],
#  [60, 11, 0.73],
#  [60, 16, 0.74],
#  [60, 21, 0.77],
#  [60, 26, 0.77],
#  [60, 31, 0.77],
#  [60, 36, 0.79],
#  [60, 41, 0.74],
#  [60, 46, 0.77],
#  [60, 51, 0.76],
#  [60, 56, 0.78],
#  [70, 1, 0.67],
#  [70, 6, 0.75],
#  [70, 11, 0.73],
#  [70, 16, 0.74],
#  [70, 21, 0.77],
#  [70, 26, 0.77],
#  [70, 31, 0.77],
#  [70, 36, 0.79],
#  [70, 41, 0.74],
#  [70, 46, 0.77],
#  [70, 51, 0.76],
# ...

# %%
result_2=pd.DataFrame(result_2)
error_2=pd.DataFrame(error_2)

# %%
pd.set_option('display.max_rows', None)
error_2.columns=['N','k','Error_Rate']
error_2
# Out:
#        N    k  Error_Rate
# 0     10    1        0.33
# 1     10    6        0.25
# 2     20    1        0.33
# 3     20    6        0.25
# 4     20   11        0.27
# 5     20   16        0.26
# 6     30    1        0.33
# 7     30    6        0.25
# 8     30   11        0.27
# 9     30   16        0.26
# 10    30   21        0.23
# 11    30   26        0.23
# 12    40    1        0.33
# 13    40    6        0.25
# 14    40   11        0.27
# 15    40   16        0.26
# 16    40   21        0.23
# 17    40   26        0.23
# 18    40   31        0.23
# 19    40   36        0.21
# 20    50    1        0.33
# 21    50    6        0.25
# 22    50   11        0.27
# 23    50   16        0.26
# 24    50   21        0.23
# 25    50   26        0.23
# 26    50   31        0.23
# 27    50   36        0.21
# 28    50   41        0.26
# 29    50   46        0.23
# 30    60    1        0.33
# 31    60    6        0.25
# 32    60   11        0.27
# 33    60   16        0.26
# ...

# %%
min_err=[]

for n in range(10,220,10):
    er=1
    if  error_2['N']==n:
        if er>error_2.Error_Rate:
            er=error_2.Error_Rate
    min_err.append([n,er])
min_err
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-0d017e52c606> in <module>
#       3 for n in range(10,220,10):
#       4     er=1
# ----> 5     if  error_2['N']==n:
#       6         if er>error_2.Error_Rate:
#       7             er=error_2.Error_Rate
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
#  smaller increments of N
error_2=[]
for N in range(3,213,3):
    c0=N//3
    c1=N-c0
    t0=train_0.iloc[:c0+1]
    t1=train_1.iloc[:c1+1]
    train_set=[t0,t1]
    train_x3=train.iloc[:,:6]
    train_y3=train.iloc[:,6]
    scaler.fit(train_x3)
    train_x3 = scaler.transform(train_x3)
    for k in range(1,N,2):
        knn=KNeighborsClassifier(n_neighbors=k)
        knn.fit(train_x3,train_y3)
        y_pred=knn.predict(test_x)
        r=accuracy_score(test_y,y_pred)
        err=1-r
        result_2.append([N,k,r])
        error_2.append([N,k,err])
        
error_2=pd.DataFrame(error_2)
pd.set_option('display.max_rows', None)
error_2.columns=['N','k','Error_Rate']
error_2
# Out:
#         N    k  Error_Rate
# 0       3    1        0.33
# 1       6    1        0.33
# 2       6    3        0.26
# 3       6    5        0.24
# 4       9    1        0.33
# 5       9    3        0.26
# 6       9    5        0.24
# 7       9    7        0.27
# 8      12    1        0.33
# 9      12    3        0.26
# 10     12    5        0.24
# 11     12    7        0.27
# 12     12    9        0.29
# 13     12   11        0.27
# 14     15    1        0.33
# 15     15    3        0.26
# 16     15    5        0.24
# 17     15    7        0.27
# 18     15    9        0.29
# 19     15   11        0.27
# 20     15   13        0.28
# 21     18    1        0.33
# 22     18    3        0.26
# 23     18    5        0.24
# 24     18    7        0.27
# 25     18    9        0.29
# 26     18   11        0.27
# 27     18   13        0.28
# 28     18   15        0.26
# 29     18   17        0.27
# 30     21    1        0.33
# 31     21    3        0.26
# 32     21    5        0.24
# ...

# %% [markdown]
# # (d)

# %% [markdown]
# ### (i)

# %% [markdown]
# ##### A

# %%
error=[]
for k in range(1,197,5):
    knn=KNeighborsClassifier(n_neighbors=k,p=1)
    knn.fit(train_x,train_y)
    y_pred=knn.predict(test_x)
    r=accuracy_score(test_y,y_pred)
    err=1-r
    error.append([k,err])

# %%
error=pd.DataFrame(error)
error.columns=['k','error_rate']
error
# Out:
#       k  error_rate
# 0     1        0.15
# 1     6        0.13
# 2    11        0.14
# 3    16        0.16
# 4    21        0.15
# 5    26        0.14
# 6    31        0.16
# 7    36        0.15
# 8    41        0.14
# 9    46        0.14
# 10   51        0.16
# 11   56        0.16
# 12   61        0.18
# 13   66        0.17
# 14   71        0.18
# 15   76        0.18
# 16   81        0.18
# 17   86        0.20
# 18   91        0.22
# 19   96        0.24
# 20  101        0.25
# 21  106        0.25
# 22  111        0.26
# 23  116        0.25
# 24  121        0.27
# 25  126        0.28
# 26  131        0.29
# 27  136        0.30
# 28  141        0.30
# 29  146        0.30
# 30  151        0.30
# 31  156        0.30
# 32  161        0.30
# 33  166        0.30
# 34  171        0.30
# 35  176        0.30
# 36  181        0.30
# 37  186        0.30
# 38  191        0.30
# 39  196        0.30

# %%
min_error=error.error_rate.min()
error[error.error_rate==min_error]
# Out:
#    k  error_rate
# 1  6        0.13

# %% [markdown]
# ##### B

# %%
error=[]
for i in range(1,11,1):
    knn=KNeighborsClassifier(n_neighbors=6,p=(10**(i/10)))
    knn.fit(train_x,train_y)
    y_pred=knn.predict(test_x)
    r=accuracy_score(test_y,y_pred)
    err=1-r
    error.append([i/10,err])
error
# Out:
# [[0.1, 0.14],
#  [0.2, 0.13],
#  [0.3, 0.13],
#  [0.4, 0.13],
#  [0.5, 0.14],
#  [0.6, 0.14],
#  [0.7, 0.15000000000000002],
#  [0.8, 0.13],
#  [0.9, 0.13],
#  [1.0, 0.12]]

# %%
error=pd.DataFrame(error)
error.columns=['log10_p','error_rate']
error
# Out:
#    log10_p  error_rate
# 0      0.1        0.14
# 1      0.2        0.13
# 2      0.3        0.13
# 3      0.4        0.13
# 4      0.5        0.14
# 5      0.6        0.14
# 6      0.7        0.15
# 7      0.8        0.13
# 8      0.9        0.13
# 9      1.0        0.12

# %%
print('The best log10_p')
min_error=error.error_rate.min()
error[error.error_rate==min_error]
# Out:
# The best log10_p
#    log10_p  error_rate
# 9      1.0        0.12

# %% [markdown]
# ##### C

# %%
error=[]
for k in range(1,197,5):
    knn=KNeighborsClassifier(n_neighbors=k,p=float('inf'))
    knn.fit(train_x,train_y)
    y_pred=knn.predict(test_x)
    r=accuracy_score(test_y,y_pred)
    err=1-r
    error.append([k,err])
error
# Out:
# [[1, 0.12],
#  [6, 0.09999999999999998],
#  [11, 0.13],
#  [16, 0.13],
#  [21, 0.15000000000000002],
#  [26, 0.13],
#  [31, 0.15000000000000002],
#  [36, 0.15000000000000002],
#  [41, 0.17000000000000004],
#  [46, 0.15000000000000002],
#  [51, 0.18000000000000005],
#  [56, 0.18000000000000005],
#  [61, 0.17000000000000004],
#  [66, 0.18000000000000005],
#  [71, 0.20999999999999996],
#  [76, 0.20999999999999996],
#  [81, 0.21999999999999997],
#  [86, 0.19999999999999996],
#  [91, 0.21999999999999997],
#  [96, 0.20999999999999996],
#  [101, 0.22999999999999998],
#  [106, 0.24],
#  [111, 0.24],
#  [116, 0.24],
#  [121, 0.22999999999999998],
#  [126, 0.27],
#  [131, 0.29000000000000004],
#  [136, 0.30000000000000004],
#  [141, 0.30000000000000004],
#  [146, 0.30000000000000004],
#  [151, 0.30000000000000004],
#  [156, 0.30000000000000004],
#  [161, 0.30000000000000004],
#  [166, 0.30000000000000004],
#  [171, 0.30000000000000004],
#  [176, 0.30000000000000004],
# ...

# %%
error=pd.DataFrame(error)
error.columns=['k','error_rate']
min_error=error.error_rate.min()
error[error.error_rate==min_error]
# Out:
#    k  error_rate
# 1  6         0.1

# %% [markdown]
# ### (ii)

# %%
train_X=train_x.copy()
DistanceMetric.get_metric('mahalanobis', V=np.cov(train_X))

# %%
test_X=test_x.copy()
DistanceMetric.get_metric('mahalanobis', VI=np.cov(test_X))

# %%
error=[]
for k in range(1,197,5):
    knn=KNeighborsClassifier(n_neighbors=k,p=1,metric='mahalanobis', metric_params={'V': np.cov(train_X,rowvar=False)})
    knn.fit(train_X,train_y)
    y_pred=knn.predict(test_X)
    r=accuracy_score(test_y,y_pred)
    err=1-r
    error.append([k,err])
error=pd.DataFrame(error)
error.columns=['k','error_rate']
min_error=error.error_rate.min()
error[error.error_rate==min_error]
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1460: FutureWarning: from version 0.25, pairwise_distances for metric='mahalanobis' will require VI to be specified if Y is passed.
#   warnings.warn("from version 0.25, pairwise_distances for "
# C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1460: FutureWarning: from version 0.25, pairwise_distances for metric='mahalanobis' will require VI to be specified if Y is passed.
#   warnings.warn("from version 0.25, pairwise_distances for "
# C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1460: FutureWarning: from version 0.25, pairwise_distances for metric='mahalanobis' will require VI to be specified if Y is passed.
#   warnings.warn("from version 0.25, pairwise_distances for "
# ...

# %% [markdown]
# # (e)

# %%
#Euclidean
error=[]
for k in range(1,197,5):
    knn=KNeighborsClassifier(n_neighbors=k,p=2,weights='distance')
    knn.fit(train_x,train_y)
    y_pred=knn.predict(test_x)
    r=accuracy_score(test_y,y_pred)
    err=1-r
    error.append([k,err])
error
# Out:
# [[1, 0.12],
#  [6, 0.14],
#  [11, 0.15000000000000002],
#  [16, 0.14],
#  [21, 0.14],
#  [26, 0.15000000000000002],
#  [31, 0.14],
#  [36, 0.15000000000000002],
#  [41, 0.14],
#  [46, 0.15000000000000002],
#  [51, 0.13],
#  [56, 0.15000000000000002],
#  [61, 0.17000000000000004],
#  [66, 0.18000000000000005],
#  [71, 0.18000000000000005],
#  [76, 0.18000000000000005],
#  [81, 0.18999999999999995],
#  [86, 0.18999999999999995],
#  [91, 0.18000000000000005],
#  [96, 0.19999999999999996],
#  [101, 0.19999999999999996],
#  [106, 0.19999999999999996],
#  [111, 0.19999999999999996],
#  [116, 0.20999999999999996],
#  [121, 0.20999999999999996],
#  [126, 0.19999999999999996],
#  [131, 0.19999999999999996],
#  [136, 0.18999999999999995],
#  [141, 0.18000000000000005],
#  [146, 0.19999999999999996],
#  [151, 0.20999999999999996],
#  [156, 0.22999999999999998],
#  [161, 0.25],
#  [166, 0.27],
#  [171, 0.28],
#  [176, 0.28],
#  [181, 0.29000000000000004],
#  [186, 0.29000000000000004],
# ...

# %%
error=pd.DataFrame(error)
error.columns=['k','error_rate']
error
# Out:
#       k  error_rate
# 0     1        0.12
# 1     6        0.14
# 2    11        0.15
# 3    16        0.14
# 4    21        0.14
# 5    26        0.15
# 6    31        0.14
# 7    36        0.15
# 8    41        0.14
# 9    46        0.15
# 10   51        0.13
# 11   56        0.15
# 12   61        0.17
# 13   66        0.18
# 14   71        0.18
# 15   76        0.18
# 16   81        0.19
# 17   86        0.19
# 18   91        0.18
# 19   96        0.20
# 20  101        0.20
# 21  106        0.20
# 22  111        0.20
# 23  116        0.21
# 24  121        0.21
# 25  126        0.20
# 26  131        0.20
# 27  136        0.19
# 28  141        0.18
# 29  146        0.20
# 30  151        0.21
# 31  156        0.23
# 32  161        0.25
# 33  166        0.27
# 34  171        0.28
# 35  176        0.28
# 36  181        0.29
# 37  186        0.29
# 38  191        0.30
# 39  196        0.30

# %%
min_error=error.error_rate.min()
error[error.error_rate==min_error]
# Out:
#    k  error_rate
# 0  1        0.12

# %%
# Manhatten
error=[]
for k in range(1,197,5):
    knn=KNeighborsClassifier(n_neighbors=k,p=1,weights='distance')
    knn.fit(train_x,train_y)
    y_pred=knn.predict(test_x)
    r=accuracy_score(test_y,y_pred)
    err=1-r
    error.append([k,err])
error
# Out:
# [[1, 0.15000000000000002],
#  [6, 0.15000000000000002],
#  [11, 0.13],
#  [16, 0.16000000000000003],
#  [21, 0.15000000000000002],
#  [26, 0.15000000000000002],
#  [31, 0.15000000000000002],
#  [36, 0.14],
#  [41, 0.15000000000000002],
#  [46, 0.14],
#  [51, 0.15000000000000002],
#  [56, 0.15000000000000002],
#  [61, 0.16000000000000003],
#  [66, 0.15000000000000002],
#  [71, 0.18999999999999995],
#  [76, 0.18000000000000005],
#  [81, 0.18999999999999995],
#  [86, 0.18999999999999995],
#  [91, 0.18000000000000005],
#  [96, 0.19999999999999996],
#  [101, 0.18999999999999995],
#  [106, 0.18999999999999995],
#  [111, 0.18999999999999995],
#  [116, 0.20999999999999996],
#  [121, 0.18999999999999995],
#  [126, 0.18999999999999995],
#  [131, 0.18999999999999995],
#  [136, 0.18999999999999995],
#  [141, 0.18999999999999995],
#  [146, 0.20999999999999996],
#  [151, 0.21999999999999997],
#  [156, 0.22999999999999998],
#  [161, 0.25],
#  [166, 0.25],
#  [171, 0.27],
#  [176, 0.28],
# ...

# %%
error=pd.DataFrame(error)
error.columns=['k','error_rate']
error
# Out:
#       k  error_rate
# 0     1        0.15
# 1     6        0.15
# 2    11        0.13
# 3    16        0.16
# 4    21        0.15
# 5    26        0.15
# 6    31        0.15
# 7    36        0.14
# 8    41        0.15
# 9    46        0.14
# 10   51        0.15
# 11   56        0.15
# 12   61        0.16
# 13   66        0.15
# 14   71        0.19
# 15   76        0.18
# 16   81        0.19
# 17   86        0.19
# 18   91        0.18
# 19   96        0.20
# 20  101        0.19
# 21  106        0.19
# 22  111        0.19
# 23  116        0.21
# 24  121        0.19
# 25  126        0.19
# 26  131        0.19
# 27  136        0.19
# 28  141        0.19
# 29  146        0.21
# 30  151        0.22
# 31  156        0.23
# 32  161        0.25
# 33  166        0.25
# 34  171        0.27
# 35  176        0.28
# 36  181        0.28
# 37  186        0.29
# 38  191        0.30
# 39  196        0.30

# %%
min_error=error.error_rate.min()
error[error.error_rate==min_error]
# Out:
#     k  error_rate
# 2  11        0.13

# %%
# Chebyshev
error=[]
for k in range(1,197,5):
    knn=KNeighborsClassifier(n_neighbors=k,p=float('inf'),weights='distance')
    knn.fit(train_x,train_y)
    y_pred=knn.predict(test_x)
    r=accuracy_score(test_y,y_pred)
    err=1-r
    error.append([k,err])
error
# Out:
# [[1, 0.12],
#  [6, 0.12],
#  [11, 0.14],
#  [16, 0.12],
#  [21, 0.14],
#  [26, 0.14],
#  [31, 0.13],
#  [36, 0.13],
#  [41, 0.14],
#  [46, 0.15000000000000002],
#  [51, 0.14],
#  [56, 0.15000000000000002],
#  [61, 0.15000000000000002],
#  [66, 0.17000000000000004],
#  [71, 0.18999999999999995],
#  [76, 0.18999999999999995],
#  [81, 0.18999999999999995],
#  [86, 0.18999999999999995],
#  [91, 0.18999999999999995],
#  [96, 0.18999999999999995],
#  [101, 0.18999999999999995],
#  [106, 0.18999999999999995],
#  [111, 0.18999999999999995],
#  [116, 0.18999999999999995],
#  [121, 0.19999999999999996],
#  [126, 0.18999999999999995],
#  [131, 0.19999999999999996],
#  [136, 0.18000000000000005],
#  [141, 0.18000000000000005],
#  [146, 0.20999999999999996],
#  [151, 0.22999999999999998],
#  [156, 0.25],
#  [161, 0.25],
#  [166, 0.27],
#  [171, 0.28],
#  [176, 0.28],
#  [181, 0.29000000000000004],
#  [186, 0.30000000000000004],
#  [191, 0.30000000000000004],
#  [196, 0.30000000000000004]]

# %%
error=pd.DataFrame(error)
error.columns=['k','error_rate']
error
# Out:
#       k  error_rate
# 0     1        0.12
# 1     6        0.12
# 2    11        0.14
# 3    16        0.12
# 4    21        0.14
# 5    26        0.14
# 6    31        0.13
# 7    36        0.13
# 8    41        0.14
# 9    46        0.15
# 10   51        0.14
# 11   56        0.15
# 12   61        0.15
# 13   66        0.17
# 14   71        0.19
# 15   76        0.19
# 16   81        0.19
# 17   86        0.19
# 18   91        0.19
# 19   96        0.19
# 20  101        0.19
# 21  106        0.19
# 22  111        0.19
# 23  116        0.19
# 24  121        0.20
# 25  126        0.19
# 26  131        0.20
# 27  136        0.18
# 28  141        0.18
# 29  146        0.21
# 30  151        0.23
# 31  156        0.25
# 32  161        0.25
# 33  166        0.27
# 34  171        0.28
# 35  176        0.28
# 36  181        0.29
# 37  186        0.30
# 38  191        0.30
# 39  196        0.30

# %%
min_error=error.error_rate.min()
error[error.error_rate==min_error]
# Out:
#     k  error_rate
# 0   1        0.12
# 1   6        0.12
# 3  16        0.12

# %% [markdown]
# # (f)

# %%
# training error for c (ii)
error=[]
for k in range(208,0,-1):
    knn=KNeighborsClassifier(n_neighbors=k)
    knn.fit(train_x,train_y)
    y_pred=knn.predict(train_x)
    r=accuracy_score(train_y,y_pred)
    err=1-r
    result.append([k,r])
    error.append([k,err])
error=pd.DataFrame(error)
error.columns=['k','error_rate']
min_error=error.error_rate.min()
error[error.error_rate==min_error]
# Out:
#      k  error_rate
# 207  1         0.0

# %%
# training error for c(iii)
error=[]
for N in range(10,220,10):
    c0=N//3
    c1=N-c0
    t0=train_0.iloc[:c0+1]
    t1=train_1.iloc[:c1+1]
    train_set=[t0,t1]
    train_x=train.iloc[:,:6]
    train_y=train.iloc[:,6]
    for k in range(1,N,5):
        knn=KNeighborsClassifier(n_neighbors=k)
        knn.fit(train_x,train_y)
        y_pred=knn.predict(train_x)
        r=accuracy_score(train_y,y_pred)
        err=1-r
        error.append([N,k,err])
        
error=pd.DataFrame(error)
error.columns=['N','k','error_rate']
min_error=error.error_rate.min()
error[error.error_rate==min_error]
# Out:
#        N  k  error_rate
# 0     10  1         0.0
# 2     20  1         0.0
# 6     30  1         0.0
# 12    40  1         0.0
# 20    50  1         0.0
# 30    60  1         0.0
# 42    70  1         0.0
# 56    80  1         0.0
# 72    90  1         0.0
# 90   100  1         0.0
# 110  110  1         0.0
# 132  120  1         0.0
# 156  130  1         0.0
# 182  140  1         0.0
# 210  150  1         0.0
# 240  160  1         0.0
# 272  170  1         0.0
# 306  180  1         0.0
# 342  190  1         0.0
# 380  200  1         0.0
# 420  210  1         0.0

# %%
# training error for d (iA)
error=[]
for k in range(1,197,5):
    knn=KNeighborsClassifier(n_neighbors=k,p=1)
    knn.fit(train_x,train_y)
    y_pred=knn.predict(train_x)
    r=accuracy_score(train_y,y_pred)
    err=1-r
    error.append([k,err])
error=pd.DataFrame(error)
error.columns=['k','error_rate']
min_error=error.error_rate.min()
error[error.error_rate==min_error]
# Out:
#    k  error_rate
# 0  1         0.0

# %%
# training error for d (iB)
error=[]
for i in range(1,11,1):
    knn=KNeighborsClassifier(n_neighbors=6,p=(10**(i/10)))
    knn.fit(train_x,train_y)
    y_pred=knn.predict(train_x)
    r=accuracy_score(train_y,y_pred)
    err=1-r
    error.append([i/10,err])
error=pd.DataFrame(error)
error.columns=['log_10','error_rate']
min_error=error.error_rate.min()
error[error.error_rate==min_error]
# Out:
#    log_10  error_rate
# 9     1.0    0.133333

# %%
# traing error for d (iC)
error=[]
for k in range(1,197,5):
    knn=KNeighborsClassifier(n_neighbors=k,p=float('inf'))
    knn.fit(train_x,train_y)
    y_pred=knn.predict(train_x)
    r=accuracy_score(train_y,y_pred)
    err=1-r
    error.append([k,err])
error=pd.DataFrame(error)
error.columns=['k','error_rate']
min_error=error.error_rate.min()
error[error.error_rate==min_error]
# Out:
#    k  error_rate
# 0  1         0.0

# %%
# training error for d (ii)

# %%
# training error for e Euclidean
error=[]
for k in range(1,197,5):
    knn=KNeighborsClassifier(n_neighbors=k,p=2,weights='distance')
    knn.fit(train_x,train_y)
    y_pred=knn.predict(train_x)
    r=accuracy_score(train_y,y_pred)
    err=1-r
    error.append([k,err])
error=pd.DataFrame(error)
error.columns=['k','error_rate']
min_error=error.error_rate.min()
error[error.error_rate==min_error]
# Out:
#       k  error_rate
# 0     1         0.0
# 1     6         0.0
# 2    11         0.0
# 3    16         0.0
# 4    21         0.0
# 5    26         0.0
# 6    31         0.0
# 7    36         0.0
# 8    41         0.0
# 9    46         0.0
# 10   51         0.0
# 11   56         0.0
# 12   61         0.0
# 13   66         0.0
# 14   71         0.0
# 15   76         0.0
# 16   81         0.0
# 17   86         0.0
# 18   91         0.0
# 19   96         0.0
# 20  101         0.0
# 21  106         0.0
# 22  111         0.0
# 23  116         0.0
# 24  121         0.0
# 25  126         0.0
# 26  131         0.0
# 27  136         0.0
# 28  141         0.0
# 29  146         0.0
# 30  151         0.0
# 31  156         0.0
# 32  161         0.0
# 33  166         0.0
# 34  171         0.0
# 35  176         0.0
# 36  181         0.0
# 37  186         0.0
# 38  191         0.0
# 39  196         0.0

# %%
# Training error for (e) Manhatten
error=[]
for k in range(1,197,5):
    knn=KNeighborsClassifier(n_neighbors=k,p=1,weights='distance')
    knn.fit(train_x,train_y)
    y_pred=knn.predict(train_x)
    r=accuracy_score(train_y,y_pred)
    err=1-r
    error.append([k,err])
error=pd.DataFrame(error)
error.columns=['k','error_rate']
min_error=error.error_rate.min()
error[error.error_rate==min_error]
# Out:
#       k  error_rate
# 0     1         0.0
# 1     6         0.0
# 2    11         0.0
# 3    16         0.0
# 4    21         0.0
# 5    26         0.0
# 6    31         0.0
# 7    36         0.0
# 8    41         0.0
# 9    46         0.0
# 10   51         0.0
# 11   56         0.0
# 12   61         0.0
# 13   66         0.0
# 14   71         0.0
# 15   76         0.0
# 16   81         0.0
# 17   86         0.0
# 18   91         0.0
# 19   96         0.0
# 20  101         0.0
# 21  106         0.0
# 22  111         0.0
# 23  116         0.0
# 24  121         0.0
# 25  126         0.0
# 26  131         0.0
# 27  136         0.0
# 28  141         0.0
# 29  146         0.0
# 30  151         0.0
# 31  156         0.0
# 32  161         0.0
# 33  166         0.0
# 34  171         0.0
# 35  176         0.0
# 36  181         0.0
# 37  186         0.0
# 38  191         0.0
# 39  196         0.0

# %%
# Training error for (e) Chebyshev
error=[]
for k in range(1,197,5):
    knn=KNeighborsClassifier(n_neighbors=k,p=float('inf'),weights='distance')
    knn.fit(train_x,train_y)
    y_pred=knn.predict(train_x)
    r=accuracy_score(train_y,y_pred)
    err=1-r
    error.append([k,err])
error=pd.DataFrame(error)
error.columns=['k','error_rate']
min_error=error.error_rate.min()
error[error.error_rate==min_error]
# Out:
#       k  error_rate
# 0     1         0.0
# 1     6         0.0
# 2    11         0.0
# 3    16         0.0
# 4    21         0.0
# 5    26         0.0
# 6    31         0.0
# 7    36         0.0
# 8    41         0.0
# 9    46         0.0
# 10   51         0.0
# 11   56         0.0
# 12   61         0.0
# 13   66         0.0
# 14   71         0.0
# 15   76         0.0
# 16   81         0.0
# 17   86         0.0
# 18   91         0.0
# 19   96         0.0
# 20  101         0.0
# 21  106         0.0
# 22  111         0.0
# 23  116         0.0
# 24  121         0.0
# 25  126         0.0
# 26  131         0.0
# 27  136         0.0
# 28  141         0.0
# 29  146         0.0
# 30  151         0.0
# 31  156         0.0
# 32  161         0.0
# 33  166         0.0
# 34  171         0.0
# 35  176         0.0
# 36  181         0.0
# 37  186         0.0
# 38  191         0.0
# 39  196         0.0

# %%
print('Lowest training error rate you achieved in this homework is 0, which can be found in many cases')
# Out:
# Lowest training error rate you achieved in this homework is 0, which can be found in many cases
