# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Inspection

# %%
df=pd.read_csv('DATA/creditcard_data.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  150000.000000  150000.000000  150000.000000  150000.000000
# mean    54194.355033      -0.242705       0.038023       0.629991
# std     21982.217623       1.819026       1.610616       1.288432
# min         0.000000     -56.407510     -72.715728     -33.680984
# 25%     38983.000000      -1.024282      -0.546727       0.126353
# 50%     55851.500000      -0.268751       0.116952       0.722469
# 75%     72675.000000       1.160957       0.799711       1.346568
# max     92348.000000       2.401777      18.902453       9.382558
#
#                   V4             V5             V6             V7  \
# count  150000.000000  150000.000000  150000.000000  150000.000000
# mean        0.128788      -0.252737       0.072127      -0.104194
# std         1.339578       1.310729       1.287130       1.163326
# min        -5.519697     -42.147898     -26.160506     -31.764946
# ...

# %%
df.shape
# Out:
# (150000, 31)

# %%
sns.countplot(x='Class',data=df)
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
data_1=len(df[df['Class']==1])
data_0=len(df[df['Class']==0])
print(f'Number of frauds = {data_1}, number of non-fraud = {data_0}')
# Out:
# Number of frauds = 293, number of non-fraud = 149707

# %%
def count_null_values(df):
    return sum(df.isnull().any(axis=1))

# %%
count_null_values(df)
# Out:
# 0

# %% [markdown]
# #### There is no missing values in this dataset

# %%
def check_datatypes(df):
    return df.dtypes

# %%
check_datatypes(df)
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %% [markdown]
# ## Plot correlation of each variables

# %%
plt.figure(figsize=(16,16))
sns.heatmap(data=df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Data Preprocessing

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df['Amount']=scaler.fit_transform(df[['Amount']])

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df=df.drop(['Time'],axis=1)
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
df=df.drop_duplicates(keep='first')

# %%
X=df.drop('Class',axis=1)
y=df['Class']

# %%
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE(random_state=69)
X_res,y_res=sm.fit_resample(X,y)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X_res,y_res,test_size=0.2,random_state=69)

# %% [markdown]
# ## Apply ML algorithms for classification

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.metrics import plot_confusion_matrix

# %%
LR=LogisticRegression()

# %%
LR.fit(X_train,y_train)
y_pred=LR.predict(X_test)
accuracy_score(y_pred,y_test)
# Out:
# 0.9541640101321662

# %%
plot_confusion_matrix(LR,X_test,y_test,normalize='all')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
lda=LinearDiscriminantAnalysis()

# %%
lda.fit(X_train,y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
y_pred=lda.predict(X_test)
accuracy_score(y_pred,y_test)
# Out:
# 0.9165302500301552

# %%
plot_confusion_matrix(lda,X_test,y_test,normalize='all')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
GNB=GaussianNB()
GNB.fit(X_train,y_train)
y_pred=GNB.predict(X_test)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.9134113349301259

# %%
plot_confusion_matrix(GNB,X_test,y_test,normalize='all')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### Turns out that logistic regression gives the best prediction out of the 3 ml algorithms
